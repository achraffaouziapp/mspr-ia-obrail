# %% [markdown]
# ### Bloc 1 — Import des bibliothèques et chargement du dataset IA
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/modeling/route_substitution_dataset.csv")

df.head()
# Out:
#    route_id  departure_station_id  arrival_station_id  departure_station_name  \
# 0         1                  4145                4154                   Tours
# 1         2                  4154                4145  Saint-Pierre-des-Corps
# 2         3                  7129                6672          Lyon Part Dieu
# 3         4                  6672                7129                   Dijon
# 4         5                  6672                7078                   Dijon
#
#      arrival_station_name     departure_city_name       arrival_city_name  \
# 0  Saint-Pierre-des-Corps                   Tours  Saint-Pierre-des-Corps
# 1                   Tours  Saint-Pierre-des-Corps                   Tours
# 2                   Dijon          Lyon Part Dieu                   Dijon
# 3          Lyon Part Dieu                   Dijon          Lyon Part Dieu
# 4           Lyon Perrache                   Dijon           Lyon Perrache
#
# ...

# %% [markdown]
# ### Bloc 2 — Vérification du nombre de lignes et de colonnes
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
df.shape
# Out:
# (4101, 35)

# %% [markdown]
# ### Bloc 3 — Contrôle des types de données et des valeurs non nulles
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4101 entries, 0 to 4100
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   route_id                4101 non-null   int64
#  1   departure_station_id    4101 non-null   int64
#  2   arrival_station_id      4101 non-null   int64
#  3   departure_station_name  4101 non-null   object
#  4   arrival_station_name    4101 non-null   object
#  5   departure_city_name     4101 non-null   object
#  6   arrival_city_name       4101 non-null   object
#  7   departure_country_name  4101 non-null   object
#  8   arrival_country_name    4101 non-null   object
#  9   departure_country_code  4101 non-null   object
#  10  arrival_country_code    4101 non-null   object
#  11  operator_name           4101 non-null   object
#  12  is_international        4101 non-null   int64
#  13  distance_km             4101 non-null   float64
# ...

# %% [markdown]
# ### Bloc 4 — Statistiques descriptives des variables numériques
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
df.describe()
# Out:
#           route_id  departure_station_id  arrival_station_id  \
# count  4101.000000           4101.000000         4101.000000
# mean   2051.917825           7005.641795         6994.655938
# std    1184.875928           9025.780654         9039.196614
# min       1.000000              4.000000            4.000000
# 25%    1026.000000           2115.000000         2045.000000
# 50%    2052.000000           4861.000000         4846.000000
# 75%    3077.000000           7478.000000         7441.000000
# max    4106.000000          40531.000000        40531.000000
#
#        is_international  distance_km   trip_count  weekly_frequency  \
# count       4101.000000  4101.000000  4101.000000       4101.000000
# mean           0.034138   167.935757    12.471836          2.529186
# std            0.181606   219.554353    20.695139          4.701459
# min            0.000000     0.050000     1.000000          0.090000
# 25%            0.000000    34.430000     1.000000          1.000000
# ...

# %% [markdown]
# ### Bloc 5 — Analyse des valeurs manquantes
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# route_id                  0
# departure_station_id      0
# arrival_station_id        0
# departure_station_name    0
# arrival_station_name      0
# departure_city_name       0
# arrival_city_name         0
# departure_country_name    0
# arrival_country_name      0
# departure_country_code    0
# arrival_country_code      0
# operator_name             0
# is_international          0
# distance_km               0
# trip_count                0
# weekly_frequency          0
# daily_frequency_avg       0
# avg_duration_minutes      0
# min_duration_minutes      0
# max_duration_minutes      0
# main_train_type           0
# has_night_train           0
# has_day_train             0
# avg_num_stops             0
# min_num_stops             0
# max_num_stops             0
# avg_quality_score         0
# min_quality_score         0
# quality_issues_count      0
# co2_train_kg              0
# co2_plane_kg              0
# co2_saving_kg             0
# co2_saving_percent        0
# ...

# %% [markdown]
# ### Bloc 6 — Répartition des classes de la variable cible
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
df["substitution_potential"].value_counts()
# Out:
# substitution_potential
# moyen     2919
# faible     733
# fort       449
# Name: count, dtype: int64

# %% [markdown]
# ### Bloc 7 — Répartition de la cible en pourcentage
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
df["substitution_potential"].value_counts(normalize=True) * 100
# Out:
# substitution_potential
# moyen     71.177762
# faible    17.873689
# fort      10.948549
# Name: proportion, dtype: float64

# %% [markdown]
# ### Bloc 8 — Vérification de la présence du score métier
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
"substitution_score" in df.columns
# Out:
# True

# %% [markdown]
# ### Bloc 9 — Statistiques descriptives du score de substitution
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
df["substitution_score"].describe()
# Out:
# count    4101.000000
# mean       50.802487
# std        10.834520
# min        27.000000
# 25%        45.000000
# 50%        45.000000
# 75%        55.000000
# max       100.000000
# Name: substitution_score, dtype: float64

# %% [markdown]
# ### Bloc 10 — Visualisation de la distribution du score de substitution
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
df["substitution_score"].hist(bins=30)
plt.title("Distribution du score de substitution avion → train")
plt.xlabel("Score de substitution")
plt.ylabel("Nombre de liaisons")
plt.show()

# %% [markdown]
# ### Bloc 11 — Recherche des liaisons avec une distance nulle
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
df[df["distance_km"] == 0][[
    "route_id",
    "departure_station_name",
    "arrival_station_name",
    "distance_km",
    "avg_duration_minutes"
]].head(10)
# Out:
# Empty DataFrame
# Columns: [route_id, departure_station_name, arrival_station_name, distance_km, avg_duration_minutes]
# Index: []

# %% [markdown]
# ### Bloc 12 — Analyse des liaisons avec les durées les plus longues
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
df.sort_values("avg_duration_minutes", ascending=False)[[
    "route_id",
    "departure_station_name",
    "arrival_station_name",
    "distance_km",
    "avg_duration_minutes",
    "has_night_train",
    "substitution_potential"
]].head(10)
# Out:
#       route_id departure_station_name arrival_station_name  distance_km  \
# 4080      4086            Wien Westbf    Київ Пасажирський      1053.92
# 3947      3953         București Nord     İstanbul Halkalı       440.00
# 3979      3985            Запоріжжя 1                Ясіня       806.44
# 4070      4076                   Суми                Рахів       828.63
# 3978      3984                  Ясіня          Запоріжжя 1       806.44
# 3985      3991        Budapest Keleti    Київ Пасажирський       893.28
# 3787      3791       Palermo Centrale      Milano Centrale       889.66
# 3939      3945                Malmö C        Innsbruck Hbf       934.58
# 3946      3952       İstanbul Halkalı       București Nord       440.00
# 4071      4077                  Рахів                 Суми       828.63
#
#       avg_duration_minutes  has_night_train substitution_potential
# 4080                1394.0                1                  moyen
# ...

# %% [markdown]
# ### Bloc 13 — Analyse des liaisons les plus fréquentes
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
df.sort_values("weekly_frequency", ascending=False)[[
    "route_id",
    "departure_station_name",
    "arrival_station_name",
    "weekly_frequency",
    "avg_duration_minutes",
    "substitution_potential"
]].head(10)
# Out:
#       route_id       departure_station_name         arrival_station_name  \
# 4100      4106                   Paris Nord               Berlin-Spandau
# 4098      4104  Prague hl.n. (main station)               Bruxelles-Midi
# 4099      4105               Berlin-Spandau                   Paris Nord
# 4097      4103               Bruxelles-Midi  Prague hl.n. (main station)
# 1087      1088                   Thionville              Luxembourg Gare
# 1086      1087              Luxembourg Gare                   Thionville
# 749        750              Genève Cornavin                   Bellegarde
# 1908      1910                     Sélestat                   Strasbourg
# 748        749                   Bellegarde              Genève Cornavin
# 1939      1941       Mulhouse Gare Centrale          Thann Saint-Jacques
#
#       weekly_frequency  avg_duration_minutes substitution_potential
# 4100             84.00                902.00                   fort
# ...

# %% [markdown]
# 1. Distribution de la cible

# %% [markdown]
# ### Bloc 14 — Répartition des classes de la variable cible
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
df["substitution_potential"].value_counts().plot(kind="bar")
plt.title("Répartition du potentiel de substitution avion → train")
plt.xlabel("Classe")
plt.ylabel("Nombre de liaisons")
plt.show()

# %% [markdown]
# 2. Distribution des distances

# %% [markdown]
# ### Bloc 15 — Distribution des distances des liaisons
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
df["distance_km"].hist(bins=30)
plt.title("Distribution des distances des liaisons")
plt.xlabel("Distance en km")
plt.ylabel("Nombre de liaisons")
plt.show()

# %% [markdown]
# 3. Distribution des durées

# %% [markdown]
# ### Bloc 16 — Distribution des durées moyennes des liaisons
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
df["avg_duration_minutes"].hist(bins=30)
plt.title("Distribution des durées moyennes")
plt.xlabel("Durée moyenne en minutes")
plt.ylabel("Nombre de liaisons")
plt.show()

# %% [markdown]
# 4. Distance par classe cible

# %% [markdown]
# ### Bloc 17 — Comparaison des distances selon la classe cible
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
df.boxplot(column="distance_km", by="substitution_potential")
plt.title("Distance selon le potentiel de substitution")
plt.suptitle("")
plt.xlabel("Potentiel")
plt.ylabel("Distance en km")
plt.show()

# %% [markdown]
# 5. Durée par classe cible

# %% [markdown]
# ### Bloc 18 — Comparaison des durées selon la classe cible
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
df.boxplot(column="avg_duration_minutes", by="substitution_potential")
plt.title("Durée selon le potentiel de substitution")
plt.suptitle("")
plt.xlabel("Potentiel")
plt.ylabel("Durée moyenne en minutes")
plt.show()

# %% [markdown]
# 6. Gain CO₂ par classe cible

# %% [markdown]
# ### Bloc 19 — Comparaison du gain CO2 selon la classe cible
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
df.boxplot(column="co2_saving_kg", by="substitution_potential")
plt.title("Gain CO₂ selon le potentiel de substitution")
plt.suptitle("")
plt.xlabel("Potentiel")
plt.ylabel("Gain CO₂ estimé en kg")
plt.show()

# %% [markdown]
# Variables retenues pour le modèle

# %% [markdown]
# ### Bloc 20 — Sélection des variables retenues pour l’analyse et la modélisation
#
# Ce bloc documente une étape précise de l’analyse exploratoire afin de rendre le notebook lisible et réutilisable.

# %%
features = [
    "is_international",
    "distance_km",
    "weekly_frequency",
    "daily_frequency_avg",
    "avg_duration_minutes",
    "min_duration_minutes",
    "max_duration_minutes",
    "has_night_train",
    "has_day_train",
    "avg_num_stops",
    "avg_quality_score",
    "quality_issues_count",
    "co2_train_kg",
    "co2_plane_kg",
    "co2_saving_kg",
    "co2_saving_percent",
]

target = "substitution_potential"

df[features + [target]].head()
# Out:
#    is_international  distance_km  weekly_frequency  daily_frequency_avg  \
# 0                 0         2.35              1.83                 0.26
# 1                 0         2.35              2.40                 0.34
# 2                 0       174.25              2.57                 0.37
# 3                 0       174.25              2.55                 0.36
# 4                 0       175.80              0.28                 0.04
#
#    avg_duration_minutes  min_duration_minutes  max_duration_minutes  \
# 0                  5.18                   5.0                   6.0
# 1                  5.19                   5.0                   7.0
# 2                118.19                 112.0                 172.0
# 3                119.45                 114.0                 142.0
# 4                128.50                 121.0                 131.0
#
#    has_night_train  has_day_train  avg_num_stops  avg_quality_score  \
# ...
